# %%
lines="""This is line1
This is line2
This is line3"""
lines
lines.splitlines()
lines.splitlines(True)
# Out:
# ['This is line1\n', 'This is line2\n', 'This is line3']

# %%
'-27'.isdigit()
'27'.isdigit()
# Out:
# True

# %%
'A9876'.isalnum()
'123 Ready Steady Go'.isalnum()
# Out:
# False
